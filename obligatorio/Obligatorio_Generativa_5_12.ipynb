# %%
import torchvision.datasets as datasets
from pathlib import Path
from collections import Counter
import torch
from torchvision.transforms import v2 as T
from torch.utils.data import DataLoader, random_split
import utils
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from torch.utils.data import Subset



from typing import Literal, List

import torchvision.models as models #para usar VGG

from PIL import Image
import os

# %%
# Montamos el checkpoint dir
CHECKPOINTS_DIR = "./modelos"
os.makedirs(CHECKPOINTS_DIR, exist_ok=True)
print("Carpeta de checkpoints:", CHECKPOINTS_DIR)

SAMPLES_DIR = "./samples"
os.makedirs(SAMPLES_DIR, exist_ok=True)
print("Carpeta de samples:", SAMPLES_DIR)
# Out:
# Carpeta de checkpoints: ./modelos
# Carpeta de samples: ./samples

# %%
transforms = T.Compose([
    T.ToImage(),
    T.ToDtype(torch.float32, scale=True),
    T.Resize((256, 256))

])

# %%
DATA_DIR = Path("data")

# %%
 #Comentamos por ahora

imagenette_dataset_train = datasets.Imagenette(
    DATA_DIR, download=False, split='train', transform=transforms
)
imagenette_dataset_val = datasets.Imagenette(
    DATA_DIR, download=False, split='val', transform=transforms
)

# %% [markdown]
# Probamos con menos imagenes

# %%
# Cargás el dataset completo
imagenette_full = datasets.Imagenette(
    DATA_DIR, download=False, split='train', transform=transforms
)

# ID de la clase (ImagenNet synset)
selected_class = imagenette_full.class_to_idx["Tinca tinca"]

# Collect all indices for the selected class
all_class_indices = [i for i, (_, label) in enumerate(imagenette_full)
                    if label == selected_class]

# Define the number of samples for train and validation
num_train_samples = 500
num_val_samples = 50

# Ensure we have enough indices for both train and validation
# If there are fewer than num_train_samples + num_val_samples, adjust
if len(all_class_indices) < (num_train_samples + num_val_samples):
    print(f"Warning: Only {len(all_class_indices)} samples available for class '{imagenette_full.classes[selected_class]}'. Adjusting split.")
    num_train_samples = min(num_train_samples, len(all_class_indices))
    num_val_samples = min(num_val_samples, len(all_class_indices) - num_train_samples)
    # Ensure val_samples is at least 1 if there's enough data for it
    if num_val_samples == 0 and (len(all_class_indices) - num_train_samples) > 0:
        num_val_samples = 1
        num_train_samples = max(0, num_train_samples - 1) # Reduce train if needed to make space for 1 val sample
    elif num_val_samples == 0 and num_train_samples == 0 and len(all_class_indices) > 0:
        # If both are 0 but there's data, put all in train
        num_train_samples = len(all_class_indices)

# Create train and validation indices
filtered_indices_train = all_class_indices[:num_train_samples]
filtered_indices_val = all_class_indices[num_train_samples : num_train_samples + num_val_samples]

# If for some reason filtered_indices_val ended up empty, and train has data, move one from train to val
if not filtered_indices_val and filtered_indices_train:
    print("Warning: Validation set is empty, but train set has data. Moving one sample from train to validation.")
    val_sample = filtered_indices_train.pop()
    filtered_indices_val.append(val_sample)

imagenette_dataset_train = Subset(imagenette_full, filtered_indices_train)
imagenette_dataset_val = Subset(imagenette_full, filtered_indices_val)

print(f"Train dataset size: {len(imagenette_dataset_train)}")
print(f"Validation dataset size: {len(imagenette_dataset_val)}")
# Out:
# Train dataset size: 500
# Validation dataset size: 50

# %%
import sys

# definimos el dispositivo que vamos a usar
DEVICE = "cpu"  # por defecto, usamos la CPU
if torch.cuda.is_available():
    DEVICE = "cuda"  # si hay GPU, usamos la GPU
elif torch.backends.mps.is_available():
    DEVICE = "mps"  # si no hay GPU, pero hay MPS, usamos MPS
elif torch.xpu.is_available():
    DEVICE = "xpu"  # si no hay GPU, pero hay XPU, usamos XPU

print(f"Usando {DEVICE}")

NUM_WORKERS = 0 # Win y MacOS pueden tener problemas con múltiples workers
if sys.platform == 'linux':
    NUM_WORKERS = 4  # numero de workers para cargar los datos (depende de cada caso)

print(f"Usando {NUM_WORKERS}")
# Out:
# Usando cuda
# Usando 4

# %%
BATCH_SIZE = 8  # tamaño del batch

# %%
def get_dataloaders(batch_size=BATCH_SIZE, num_workers=NUM_WORKERS):
    train_loader = DataLoader(
        imagenette_dataset_train,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
    )

    val_loader = DataLoader(
        imagenette_dataset_val,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
    )

    return train_loader, val_loader


train_loader, val_loader = get_dataloaders()

# %%
class DoubleConv(nn.Module):

  def __init__(self, in_ch: int, out_ch: int,
               norm: Literal['bn','gn','none'] = 'bn',
               groups: int = 8,
               dropout: float = 0.0):
    super().__init__()
    self.conv1 = nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1, bias=(norm=='none'))
    self.conv2 = nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1, bias=(norm=='none'))
    self.norm1 = self._make_norm(norm, out_ch, groups)
    self.norm2 = self._make_norm(norm, out_ch, groups)
    #self.drop = nn.Dropout2d(dropout) if dropout and dropout > 0 else nn.Identity()
    self.act = nn.ReLU(inplace=True)

  @staticmethod
  def _make_norm(kind: str, num_ch: int, groups: int):
    if kind == 'bn':
      return nn.BatchNorm2d(num_ch)
    if kind == 'gn':
      g = min(groups, num_ch) if num_ch % groups == 0 else 1
      return nn.GroupNorm(g, num_ch)
    return nn.Identity()


  def forward(self, x: torch.Tensor) -> torch.Tensor:
    x = self.conv1(x)
    x = self.norm1(x)
    x = self.act(x)
    #x = self.drop(x)
    x = self.conv2(x)
    x = self.norm2(x)
    x = self.act(x)
    return x

# %%
class Down(nn.Module):
#Downscaling with maxpool then double conv
  def __init__(self, in_ch: int, out_ch: int,
                 norm: str = 'bn',
                 groups: int = 8,
                 dropout: float = 0.0):
        super().__init__()
        self.pool = nn.MaxPool2d(2)
        self.block = DoubleConv(in_ch, out_ch, norm=norm, groups=groups, dropout=dropout)

  def forward(self, x):
      x = self.pool(x)
      x = self.block(x)
      return x

# %%
class Up(nn.Module):
  """Upscaling then double conv
  If bilinear: use Upsample, else learned ConvTranspose2d
  """
  def __init__(self, in_ch: int, out_ch: int, bilinear: bool = True, norm: str = 'bn', groups: int = 8, dropout: float = 0.0):
    super().__init__()
    if bilinear:
      self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
      self.reduce = nn.Conv2d(in_ch, in_ch // 2, kernel_size=1)
      conv_in = in_ch // 2 + out_ch # after concat with skip (which has out_ch channels)
    else:
      self.up = nn.ConvTranspose2d(in_ch, in_ch // 2, kernel_size=2, stride=2)
      self.reduce = nn.Identity()
      conv_in = in_ch // 2 + out_ch
    self.block = DoubleConv(conv_in, out_ch, norm=norm, groups=groups, dropout=dropout)


  @staticmethod
  def _pad_to_match(x: torch.Tensor, ref: torch.Tensor) -> torch.Tensor:
    """Pad x on the right/bottom to match spatial size of ref."""
    diff_y = ref.size(2) - x.size(2)
    diff_x = ref.size(3) - x.size(3)
    if diff_x == 0 and diff_y == 0:
      return x
    return F.pad(x, [0, diff_x, 0, diff_y])


  def forward(self, x: torch.Tensor, skip: torch.Tensor) -> torch.Tensor:
    x = self.up(x)
    x = self.reduce(x)
    x = self._pad_to_match(x, skip)
    # concat along channel dim
    x = torch.cat([skip, x], dim=1)
    x = self.block(x)
    return x

# %%
class OutConv(nn.Module):
  def __init__(self, in_ch: int, out_ch: int=3):
    super().__init__()
    self.conv = nn.Conv2d(in_ch, out_ch, kernel_size=1)

  def forward(self, x):
    return self.conv(x)

# %%
class UNet(nn.Module):
    def __init__(self,
                 in_channels=1,
                 base_ch=64,
                 depth=4,              # número de downs (pools), igual que el paper
                 bilinear=True,
                 norm='bn',
                 dropout=0.0):
        super().__init__()

        # Ej: base_ch=64, depth=4 -> [64, 128, 256, 512, 1024]
        # chs[0]..chs[depth] son los canales en cada nivel de resolución
        chs = [base_ch * (2 ** i) for i in range(depth + 1)]

        # Encoder
        self.inc = DoubleConv(in_channels, chs[0], norm=norm, dropout=dropout)

        self.downs = nn.ModuleList()
        # Creamos 'depth' downs con maxpool (como el paper)
        for i in range(depth):
            self.downs.append(
                Down(chs[i], chs[i + 1], norm=norm, dropout=dropout)
            )

        # Decoder
        self.ups = nn.ModuleList()
        cur_ch = chs[-1]  # canales del nivel más profundo (ej 1024)

        # Vamos subiendo desde el fondo hasta el tope
        # i = depth-1, depth-2, ..., 0  -> skip channels = chs[i]
        for i in reversed(range(depth)):
            self.ups.append(
                Up(cur_ch, chs[i], bilinear=bilinear, norm=norm, dropout=dropout)
            )
            cur_ch = chs[i]

        self.outc = OutConv(cur_ch, 3)
        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

    def forward(self, x):
        skips = []

        # Primer nivel (sin pool)
        x = self.inc(x)
        skips.append(x)

        # Encoder con 'depth' downs (cada uno hace pool + convs)
        for down in self.downs:
            x = down(x)
            skips.append(x)

        # Ahora x está en el nivel más profundo, mismo que skips[-1]
        # No hay bottleneck extra: el último Down ya es el bloque profundo.

        # Decoder: empezamos desde la representación profunda
        x = skips.pop()  # nivel más profundo

        for up in self.ups:
            skip = skips.pop()   # skip correspondiente de encoder
            x = up(x, skip)

        x = self.outc(x)
        return x

# %%
class StyleTransferNet(nn.Module):
    def __init__(self, **unet_kwargs):
        super().__init__()
        self.transform = UNet(**unet_kwargs)

    def forward(self, x):
        return self.transform(x)

# %%
IMAGENET_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1,3,1,1)
IMAGENET_STD  = torch.tensor([0.229, 0.224, 0.225]).view(1,3,1,1)

# %%
def vgg_normalize(x: torch.Tensor) -> torch.Tensor:
    # x debe estar en [0,1] para esto. Si tu U-Net devuelve [-1,1], primero reescalá.
    return (x - IMAGENET_MEAN.to(x.device)) / IMAGENET_STD.to(x.device)

# %%
class VGGFeatureExtractor(nn.Module):
    """
    Devuelve features de capas intermedias.
    Las indices dependen de la definicion de vgg19.features
    """
    def __init__(self, content_layers=None, style_layers=None):
        super().__init__()
        vgg = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1).features
        self.vgg = vgg.eval()
        for p in self.vgg.parameters():
            p.requires_grad = False

        # indices de capas (puedes ajustarlos)
        # estos corresponden a relu1_2, relu2_2, relu3_3, relu4_3 aprox.
        self.content_layers = content_layers or ['8']      # por ej relu2_2
        self.style_layers   = style_layers   or ['3','8','15','22']

    def forward(self, x):
        features = {}
        for i, layer in enumerate(self.vgg):
            x = layer(x)
            name = str(i)
            if name in self.content_layers or name in self.style_layers:
                features[name] = x
        return features

# %%
def gram_matrix(feat: torch.Tensor) -> torch.Tensor:
    # feat: [B, C, H, W]
    B, C, H, W = feat.shape
    F_ = feat.view(B, C, H * W)
    G = torch.bmm(F_, F_.transpose(1, 2))  # [B, C, C]
    return G / (C * H * W)


def total_variation_loss(x: torch.Tensor) -> torch.Tensor:
    # suaviza la imagen, penaliza cambios bruscos
    loss_h = torch.mean(torch.abs(x[:, :, 1:, :] - x[:, :, :-1, :]))
    loss_w = torch.mean(torch.abs(x[:, :, :, 1:] - x[:, :, :, :-1]))
    return loss_h + loss_w

# %%
class PerceptualLoss(nn.Module):
    def __init__(self,
                 vgg_extractor: VGGFeatureExtractor,
                 style_img: torch.Tensor,
                 content_weight=0.01,
                 style_weight=1e4,
                 tv_weight=1e-6):
        super().__init__()
        self.vgg = vgg_extractor
        self.cw = content_weight
        self.sw = style_weight
        self.tvw = tv_weight

        with torch.no_grad():
            # estilo en [0,1] y normalizado a ImageNet
            self.style_grams = self._compute_style_grams(style_img)

    def _compute_style_grams(self, style_img: torch.Tensor):

        # style_img debería ser [1, 3, 256, 256] en [0,1]
        assert style_img.dim() == 4, f"style_img dim {style_img.dim()}"
        B, C, H, W = style_img.shape
        assert C == 3, f"style_img C={C}, esperado 3"
        assert H >= 64 and W >= 64, f"style_img muy chica: {H}x{W}"


        """
        style_img: [1,3,H,W] en [0,1]
        """
        style_norm = vgg_normalize(style_img)
        feats = self.vgg(style_norm)
        grams = {}
        for name in self.vgg.style_layers:
            grams[name] = gram_matrix(feats[name])
        return grams

    def forward(self, output: torch.Tensor, content: torch.Tensor) -> torch.Tensor:
        for name, t in [("output", output), ("content", content)]:
          assert t.dim() == 4, f"{name} dim {t.dim()}"
          B, C, H, W = t.shape
          assert C == 3, f"{name} C={C}, esperado 3"
          assert H >= 64 and W >= 64, f"{name} muy chico: {H}x{W}"
        """
        output, content: [B,3,H,W], ambos en [0,1]
        """
        out_norm = vgg_normalize(output)
        cont_norm = vgg_normalize(content)

        feats_out = self.vgg(out_norm)
        feats_cont = self.vgg(cont_norm)

        # Content loss: usar una sola capa (ej relu2_2 -> '8')
        content_loss = 0.0
        for name in self.vgg.content_layers:
            content_loss += F.mse_loss(feats_out[name], feats_cont[name])

        # Style loss: comparar Gram matrices
        style_loss = 0.0
        for name in self.vgg.style_layers:
            G_out = gram_matrix(feats_out[name])   # [B, C, C]
            G_style = self.style_grams[name]       # [1, C, C]

            # replicar el estilo para que tenga el mismo batch size
            if G_style.size(0) == 1 and G_out.size(0) > 1:
                G_style = G_style.expand(G_out.size(0), -1, -1)  # [B, C, C]

            style_loss += F.mse_loss(G_out, G_style)

        tv_loss = total_variation_loss(output)

        loss = self.cw * content_loss + self.sw * style_loss + self.tvw * tv_loss
        return loss, content_loss, style_loss, tv_loss

# %%
model = StyleTransferNet(
    in_channels=3,
    base_ch=64, # era 64. lo baje porque me daba error de capacidad la GPU
    depth=4,
    bilinear=True,
    norm='gn',
    dropout=0.0,
).to(DEVICE)

# %%
vgg_extractor = VGGFeatureExtractor(
    content_layers=['8'],                 # una capa para contenido
    style_layers=['3', '8', '15', '22']   # varias capas para estilo
).to(DEVICE)

# %%
style_transform = T.Compose([
    T.ToImage(),
    T.ToDtype(torch.float32, scale=True),
    T.Resize((256,256)),
])

# %% [markdown]
# ## Cargamos la imágen de estilo
#
# Utilizaremos como imágen de estilo para nuestra red la obra "Starry Night" de Vincent van Gogh

# %%
# Cargo imagen de estilo
style_img_pil = Image.open("style_img.jpg").convert("RGB")

# %%
style_img = style_transform(style_img_pil).unsqueeze(0).to(DEVICE)

# %%
style_img.shape
# Out:
# torch.Size([1, 3, 256, 256])

# %%
#mostramos la style_img
plt.imshow(style_img.cpu().squeeze(0).permute(1, 2, 0).numpy())

# %%
criterion = PerceptualLoss(
    vgg_extractor=vgg_extractor,
    style_img=style_img,
    content_weight=0.05,
    style_weight=1e4,
    tv_weight=1e-6
)

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=1e-3,
    betas=(0.9, 0.999)
)

# %%
train_loss, val_loss, epoch_val_content_loss ,epoch_val_style_loss ,epoch_val_ltv_loss  = utils.train(model,optimizer,criterion,train_loader,val_loader,DEVICE,do_early_stopping=True,patience=35,epochs = 500,ruta_img = SAMPLES_DIR,CHECKPOINTS_DIR=CHECKPOINTS_DIR)
# Out:
# Saved model checkpoint to ./modelos/model_epoch_000.pth
# Epoch: 001 | Train Loss: 6.67653 | Val Loss: 2.46094
# Epoch: 002 | Train Loss: 1.78862 | Val Loss: 1.39031
# Epoch: 003 | Train Loss: 1.25712 | Val Loss: 1.30599
# Epoch: 004 | Train Loss: 1.12058 | Val Loss: 1.06308
# Epoch: 005 | Train Loss: 0.99563 | Val Loss: 1.02348
# Epoch: 006 | Train Loss: 0.91120 | Val Loss: 0.84730
# Epoch: 007 | Train Loss: 0.82629 | Val Loss: 0.79979
# Epoch: 008 | Train Loss: 0.78364 | Val Loss: 0.82722
# Epoch: 009 | Train Loss: 0.75157 | Val Loss: 0.74557
# Epoch: 010 | Train Loss: 0.71827 | Val Loss: 0.71395
# Epoch: 011 | Train Loss: 0.69894 | Val Loss: 0.68490
# Epoch: 012 | Train Loss: 0.67571 | Val Loss: 0.68816
# Epoch: 013 | Train Loss: 0.66210 | Val Loss: 0.69905
# Epoch: 014 | Train Loss: 0.65105 | Val Loss: 0.68133
# Epoch: 015 | Train Loss: 0.63398 | Val Loss: 0.66619
# Epoch: 016 | Train Loss: 0.62362 | Val Loss: 0.61671
# Epoch: 017 | Train Loss: 0.61293 | Val Loss: 0.63430
# Epoch: 018 | Train Loss: 0.59905 | Val Loss: 0.59818
# Epoch: 019 | Train Loss: 0.58915 | Val Loss: 0.58639
# Epoch: 020 | Train Loss: 0.57639 | Val Loss: 0.57301
# Epoch: 021 | Train Loss: 0.56816 | Val Loss: 0.57819
# Epoch: 022 | Train Loss: 0.55675 | Val Loss: 0.56150
# Epoch: 023 | Train Loss: 0.55466 | Val Loss: 0.57652
# Epoch: 024 | Train Loss: 0.54913 | Val Loss: 0.55520
# Epoch: 025 | Train Loss: 0.53341 | Val Loss: 0.54655
# Epoch: 026 | Train Loss: 0.52946 | Val Loss: 0.52497
# Epoch: 027 | Train Loss: 0.52269 | Val Loss: 0.53407
# Epoch: 028 | Train Loss: 0.51438 | Val Loss: 0.52917
# Epoch: 029 | Train Loss: 0.51004 | Val Loss: 0.51732
# Epoch: 030 | Train Loss: 0.49977 | Val Loss: 0.52322
# Epoch: 031 | Train Loss: 0.51227 | Val Loss: 0.51892
# Epoch: 032 | Train Loss: 0.49558 | Val Loss: 0.50208
# Epoch: 033 | Train Loss: 0.48897 | Val Loss: 0.49081
# Epoch: 034 | Train Loss: 0.48768 | Val Loss: 0.48877
# Epoch: 035 | Train Loss: 0.48199 | Val Loss: 0.48152
# Epoch: 036 | Train Loss: 0.47972 | Val Loss: 0.51536
# Epoch: 037 | Train Loss: 0.47906 | Val Loss: 0.48540
# Epoch: 038 | Train Loss: 0.46409 | Val Loss: 0.46578
# Epoch: 039 | Train Loss: 0.46324 | Val Loss: 0.46552
# Epoch: 040 | Train Loss: 0.44894 | Val Loss: 0.46578
# Epoch: 041 | Train Loss: 0.45071 | Val Loss: 0.44718
# Epoch: 042 | Train Loss: 0.44250 | Val Loss: 0.45055
# Epoch: 043 | Train Loss: 0.44796 | Val Loss: 0.45393
# Epoch: 044 | Train Loss: 0.43663 | Val Loss: 0.44362
# Epoch: 045 | Train Loss: 0.43902 | Val Loss: 0.44644
# Epoch: 046 | Train Loss: 0.43195 | Val Loss: 0.42523
# Epoch: 047 | Train Loss: 0.42273 | Val Loss: 0.43790
# Epoch: 048 | Train Loss: 0.42235 | Val Loss: 0.42626
# Epoch: 049 | Train Loss: 0.41767 | Val Loss: 0.43600
# Epoch: 050 | Train Loss: 0.41879 | Val Loss: 0.41737
# Saved model checkpoint to ./modelos/model_epoch_050.pth
# Epoch: 051 | Train Loss: 0.40361 | Val Loss: 0.40515
# Epoch: 052 | Train Loss: 0.40608 | Val Loss: 0.41374
# Epoch: 053 | Train Loss: 0.40210 | Val Loss: 0.40644
# Epoch: 054 | Train Loss: 0.39854 | Val Loss: 0.40950
# Epoch: 055 | Train Loss: 0.39527 | Val Loss: 0.39913
# Epoch: 056 | Train Loss: 0.39449 | Val Loss: 0.40202
# Epoch: 057 | Train Loss: 0.39233 | Val Loss: 0.39124
# Epoch: 058 | Train Loss: 0.38573 | Val Loss: 0.40722
# Epoch: 059 | Train Loss: 0.38600 | Val Loss: 0.38586
# Epoch: 060 | Train Loss: 0.37878 | Val Loss: 0.38267
# Epoch: 061 | Train Loss: 0.37511 | Val Loss: 0.38665
# Epoch: 062 | Train Loss: 0.37614 | Val Loss: 0.38787
# Epoch: 063 | Train Loss: 0.37211 | Val Loss: 0.38583
# Epoch: 064 | Train Loss: 0.36764 | Val Loss: 0.37772
# Epoch: 065 | Train Loss: 0.36280 | Val Loss: 0.37254
# Epoch: 066 | Train Loss: 0.36119 | Val Loss: 0.36935
# Epoch: 067 | Train Loss: 0.36263 | Val Loss: 0.37720
# Epoch: 068 | Train Loss: 0.36401 | Val Loss: 0.36754
# Epoch: 069 | Train Loss: 0.35496 | Val Loss: 0.35957
# Epoch: 070 | Train Loss: 0.35125 | Val Loss: 0.37254
# Epoch: 071 | Train Loss: 0.35422 | Val Loss: 0.36400
# Epoch: 072 | Train Loss: 0.34555 | Val Loss: 0.35931
# Epoch: 073 | Train Loss: 0.35529 | Val Loss: 0.37065
# Epoch: 074 | Train Loss: 0.34580 | Val Loss: 0.35763
# Epoch: 075 | Train Loss: 0.34161 | Val Loss: 0.36949
# Epoch: 076 | Train Loss: 0.34504 | Val Loss: 0.35916
# Epoch: 077 | Train Loss: 0.34520 | Val Loss: 0.36097
# Epoch: 078 | Train Loss: 0.34262 | Val Loss: 0.34871
# Epoch: 079 | Train Loss: 0.33697 | Val Loss: 0.35799
# Epoch: 080 | Train Loss: 0.33135 | Val Loss: 0.35018
# Epoch: 081 | Train Loss: 0.33425 | Val Loss: 0.35248
# Epoch: 082 | Train Loss: 0.33583 | Val Loss: 0.35042
# Epoch: 083 | Train Loss: 0.33145 | Val Loss: 0.34241
# Epoch: 084 | Train Loss: 0.32499 | Val Loss: 0.34862
# Epoch: 085 | Train Loss: 0.33084 | Val Loss: 0.36140
# Epoch: 086 | Train Loss: 0.32850 | Val Loss: 0.36041
# Epoch: 087 | Train Loss: 0.32433 | Val Loss: 0.35041
# Epoch: 088 | Train Loss: 0.32290 | Val Loss: 0.33880
# Epoch: 089 | Train Loss: 0.31986 | Val Loss: 0.33791
# Epoch: 090 | Train Loss: 0.31788 | Val Loss: 0.34531
# Epoch: 091 | Train Loss: 0.31677 | Val Loss: 0.33686
# Epoch: 092 | Train Loss: 0.31581 | Val Loss: 0.34565
# Epoch: 093 | Train Loss: 0.31443 | Val Loss: 0.33659
# Epoch: 094 | Train Loss: 0.31454 | Val Loss: 0.33618
# Epoch: 095 | Train Loss: 0.31183 | Val Loss: 0.33284
# Epoch: 096 | Train Loss: 0.31483 | Val Loss: 0.33509
# Epoch: 097 | Train Loss: 0.31204 | Val Loss: 0.33473
# Epoch: 098 | Train Loss: 0.31153 | Val Loss: 0.34637
# Epoch: 099 | Train Loss: 0.31290 | Val Loss: 0.33573
# Epoch: 100 | Train Loss: 0.30392 | Val Loss: 0.32664
# Saved model checkpoint to ./modelos/model_epoch_100.pth
# Epoch: 101 | Train Loss: 0.30704 | Val Loss: 0.33011
# Epoch: 102 | Train Loss: 0.31045 | Val Loss: 0.33549
# Epoch: 103 | Train Loss: 0.30436 | Val Loss: 0.33498
# Epoch: 104 | Train Loss: 0.30264 | Val Loss: 0.33683
# Epoch: 105 | Train Loss: 0.30164 | Val Loss: 0.32714
# Epoch: 106 | Train Loss: 0.29868 | Val Loss: 0.32795
# Epoch: 107 | Train Loss: 0.29900 | Val Loss: 0.32903
# Epoch: 108 | Train Loss: 0.29885 | Val Loss: 0.32485
# Epoch: 109 | Train Loss: 0.29910 | Val Loss: 0.33807
# Epoch: 110 | Train Loss: 0.29836 | Val Loss: 0.32801
# Epoch: 111 | Train Loss: 0.29322 | Val Loss: 0.34559
# Epoch: 112 | Train Loss: 0.29876 | Val Loss: 0.32126
# Epoch: 113 | Train Loss: 0.29864 | Val Loss: 0.32591
# Epoch: 114 | Train Loss: 0.29177 | Val Loss: 0.31773
# Epoch: 115 | Train Loss: 0.29070 | Val Loss: 0.32604
# Epoch: 116 | Train Loss: 0.28889 | Val Loss: 0.32221
# Epoch: 117 | Train Loss: 0.28686 | Val Loss: 0.31975
# Epoch: 118 | Train Loss: 0.29080 | Val Loss: 0.32250
# Epoch: 119 | Train Loss: 0.28703 | Val Loss: 0.31900
# Epoch: 120 | Train Loss: 0.28520 | Val Loss: 0.31846
# Epoch: 121 | Train Loss: 0.28256 | Val Loss: 0.31365
# Epoch: 122 | Train Loss: 0.28542 | Val Loss: 0.32736
# Epoch: 123 | Train Loss: 0.28240 | Val Loss: 0.31821
# Epoch: 124 | Train Loss: 0.28524 | Val Loss: 0.32837
# Epoch: 125 | Train Loss: 0.28504 | Val Loss: 0.32356
# Epoch: 126 | Train Loss: 0.28483 | Val Loss: 0.31637
# Epoch: 127 | Train Loss: 0.27995 | Val Loss: 0.31488
# Epoch: 128 | Train Loss: 0.27998 | Val Loss: 0.31243
# Epoch: 129 | Train Loss: 0.27492 | Val Loss: 0.31287
# Epoch: 130 | Train Loss: 0.27851 | Val Loss: 0.31520
# Epoch: 131 | Train Loss: 0.27660 | Val Loss: 0.30721
# Epoch: 132 | Train Loss: 0.27496 | Val Loss: 0.31621
# Epoch: 133 | Train Loss: 0.27751 | Val Loss: 0.31331
# Epoch: 134 | Train Loss: 0.27652 | Val Loss: 0.32419
# Epoch: 135 | Train Loss: 0.27727 | Val Loss: 0.31665
# Epoch: 136 | Train Loss: 0.27715 | Val Loss: 0.31466
# Epoch: 137 | Train Loss: 0.27490 | Val Loss: 0.30980
# Epoch: 138 | Train Loss: 0.27124 | Val Loss: 0.31291
# Epoch: 139 | Train Loss: 0.27208 | Val Loss: 0.30551
# Epoch: 140 | Train Loss: 0.27162 | Val Loss: 0.30735
# Epoch: 141 | Train Loss: 0.26767 | Val Loss: 0.30921
# Epoch: 142 | Train Loss: 0.26692 | Val Loss: 0.30739
# Epoch: 143 | Train Loss: 0.26864 | Val Loss: 0.30775
# Epoch: 144 | Train Loss: 0.26931 | Val Loss: 0.30432
# Epoch: 145 | Train Loss: 0.27042 | Val Loss: 0.30465
# Epoch: 146 | Train Loss: 0.26281 | Val Loss: 0.30344
# Epoch: 147 | Train Loss: 0.26365 | Val Loss: 0.30278
# Epoch: 148 | Train Loss: 0.26944 | Val Loss: 0.31315
# Epoch: 149 | Train Loss: 0.27031 | Val Loss: 0.30637
# Epoch: 150 | Train Loss: 0.26726 | Val Loss: 0.30288
# Saved model checkpoint to ./modelos/model_epoch_150.pth
# Epoch: 151 | Train Loss: 0.26035 | Val Loss: 0.30231
# Epoch: 152 | Train Loss: 0.25827 | Val Loss: 0.30022
# Epoch: 153 | Train Loss: 0.26090 | Val Loss: 0.30068
# Epoch: 154 | Train Loss: 0.26265 | Val Loss: 0.30231
# Epoch: 155 | Train Loss: 0.26165 | Val Loss: 0.30208
# Epoch: 156 | Train Loss: 0.26349 | Val Loss: 0.30380
# Epoch: 157 | Train Loss: 0.26209 | Val Loss: 0.30303
# Epoch: 158 | Train Loss: 0.25799 | Val Loss: 0.30027
# Epoch: 159 | Train Loss: 0.25693 | Val Loss: 0.29668
# Epoch: 160 | Train Loss: 0.25771 | Val Loss: 0.29837
# Epoch: 161 | Train Loss: 0.25606 | Val Loss: 0.30645
# Epoch: 162 | Train Loss: 0.25518 | Val Loss: 0.29846
# Epoch: 163 | Train Loss: 0.25653 | Val Loss: 0.29931
# Epoch: 164 | Train Loss: 0.25080 | Val Loss: 0.29752
# Epoch: 165 | Train Loss: 0.25470 | Val Loss: 0.29735
# Epoch: 166 | Train Loss: 0.25504 | Val Loss: 0.29874
# Epoch: 167 | Train Loss: 0.25423 | Val Loss: 0.29547
# Epoch: 168 | Train Loss: 0.25241 | Val Loss: 0.29726
# Epoch: 169 | Train Loss: 0.24921 | Val Loss: 0.29331
# Epoch: 170 | Train Loss: 0.25078 | Val Loss: 0.30672
# Epoch: 171 | Train Loss: 0.25436 | Val Loss: 0.30318
# Epoch: 172 | Train Loss: 0.25414 | Val Loss: 0.29624
# Epoch: 173 | Train Loss: 0.25227 | Val Loss: 0.29750
# Epoch: 174 | Train Loss: 0.24850 | Val Loss: 0.30169
# Epoch: 175 | Train Loss: 0.25327 | Val Loss: 0.29657
# Epoch: 176 | Train Loss: 0.25092 | Val Loss: 0.29900
# Epoch: 177 | Train Loss: 0.24741 | Val Loss: 0.29117
# Epoch: 178 | Train Loss: 0.24442 | Val Loss: 0.29757
# Epoch: 179 | Train Loss: 0.24554 | Val Loss: 0.29466
# Epoch: 180 | Train Loss: 0.24259 | Val Loss: 0.29682
# Epoch: 181 | Train Loss: 0.24417 | Val Loss: 0.30414
# Epoch: 182 | Train Loss: 0.24774 | Val Loss: 0.29603
# Epoch: 183 | Train Loss: 0.24454 | Val Loss: 0.29695
# Epoch: 184 | Train Loss: 0.24576 | Val Loss: 0.29292
# Epoch: 185 | Train Loss: 0.24391 | Val Loss: 0.29138
# Epoch: 186 | Train Loss: 0.24355 | Val Loss: 0.29094
# Epoch: 187 | Train Loss: 0.24203 | Val Loss: 0.28708
# Epoch: 188 | Train Loss: 0.24082 | Val Loss: 0.29420
# Epoch: 189 | Train Loss: 0.24188 | Val Loss: 0.29855
# Epoch: 190 | Train Loss: 0.24566 | Val Loss: 0.29443
# Epoch: 191 | Train Loss: 0.24449 | Val Loss: 0.29645
# Epoch: 192 | Train Loss: 0.24556 | Val Loss: 0.29419
# Epoch: 193 | Train Loss: 0.24126 | Val Loss: 0.29220
# Epoch: 194 | Train Loss: 0.23682 | Val Loss: 0.29307
# Epoch: 195 | Train Loss: 0.23914 | Val Loss: 0.30963
# Epoch: 196 | Train Loss: 0.23917 | Val Loss: 0.29523
# Epoch: 197 | Train Loss: 0.23684 | Val Loss: 0.28839
# Epoch: 198 | Train Loss: 0.23399 | Val Loss: 0.29071
# Epoch: 199 | Train Loss: 0.23579 | Val Loss: 0.29425
# Epoch: 200 | Train Loss: 0.24040 | Val Loss: 0.29672
# Saved model checkpoint to ./modelos/model_epoch_200.pth
# Epoch: 201 | Train Loss: 0.23999 | Val Loss: 0.29345
# Epoch: 202 | Train Loss: 0.23624 | Val Loss: 0.28586
# Epoch: 203 | Train Loss: 0.23450 | Val Loss: 0.28809
# Epoch: 204 | Train Loss: 0.23123 | Val Loss: 0.28288
# Epoch: 205 | Train Loss: 0.23134 | Val Loss: 0.28900
# Epoch: 206 | Train Loss: 0.23279 | Val Loss: 0.29036
# Epoch: 207 | Train Loss: 0.23413 | Val Loss: 0.29048
# Epoch: 208 | Train Loss: 0.23425 | Val Loss: 0.29870
# Epoch: 209 | Train Loss: 0.23584 | Val Loss: 0.29209
# Epoch: 210 | Train Loss: 0.23577 | Val Loss: 0.29145
# Epoch: 211 | Train Loss: 0.23210 | Val Loss: 0.28716
# Epoch: 212 | Train Loss: 0.23374 | Val Loss: 0.29302
# Epoch: 213 | Train Loss: 0.23239 | Val Loss: 0.28487
# Epoch: 214 | Train Loss: 0.22849 | Val Loss: 0.28737
# Epoch: 215 | Train Loss: 0.23617 | Val Loss: 0.29027
# Epoch: 216 | Train Loss: 0.23031 | Val Loss: 0.28630
# Epoch: 217 | Train Loss: 0.22667 | Val Loss: 0.28486
# Epoch: 218 | Train Loss: 0.22887 | Val Loss: 0.28589
# Epoch: 219 | Train Loss: 0.22708 | Val Loss: 0.28282
# Epoch: 220 | Train Loss: 0.22859 | Val Loss: 0.29004
# Epoch: 221 | Train Loss: 0.22918 | Val Loss: 0.28866
# Epoch: 222 | Train Loss: 0.22967 | Val Loss: 0.29165
# Epoch: 223 | Train Loss: 0.23410 | Val Loss: 0.28741
# Epoch: 224 | Train Loss: 0.23082 | Val Loss: 0.29323
# Epoch: 225 | Train Loss: 0.22850 | Val Loss: 0.28145
# Epoch: 226 | Train Loss: 0.22363 | Val Loss: 0.27986
# Epoch: 227 | Train Loss: 0.22300 | Val Loss: 0.28494
# Epoch: 228 | Train Loss: 0.22376 | Val Loss: 0.28341
# Epoch: 229 | Train Loss: 0.22115 | Val Loss: 0.28823
# Epoch: 230 | Train Loss: 0.22342 | Val Loss: 0.28852
# Epoch: 231 | Train Loss: 0.22659 | Val Loss: 0.28736
# Epoch: 232 | Train Loss: 0.22776 | Val Loss: 0.30190
# Epoch: 233 | Train Loss: 0.22598 | Val Loss: 0.28602
# Epoch: 234 | Train Loss: 0.22733 | Val Loss: 0.28692
# Epoch: 235 | Train Loss: 0.23273 | Val Loss: 0.28883
# Epoch: 236 | Train Loss: 0.23175 | Val Loss: 0.28633
# Epoch: 237 | Train Loss: 0.22621 | Val Loss: 0.28287
# Epoch: 238 | Train Loss: 0.22148 | Val Loss: 0.28007
# Epoch: 239 | Train Loss: 0.21919 | Val Loss: 0.28152
# Epoch: 240 | Train Loss: 0.22279 | Val Loss: 0.28609
# Epoch: 241 | Train Loss: 0.22138 | Val Loss: 0.27982
# Epoch: 242 | Train Loss: 0.21890 | Val Loss: 0.27934
# Epoch: 243 | Train Loss: 0.21948 | Val Loss: 0.27932
# Epoch: 244 | Train Loss: 0.22014 | Val Loss: 0.28841
# Epoch: 245 | Train Loss: 0.22295 | Val Loss: 0.28502
# Epoch: 246 | Train Loss: 0.21934 | Val Loss: 0.28096
# Epoch: 247 | Train Loss: 0.21718 | Val Loss: 0.28358
# Epoch: 248 | Train Loss: 0.21581 | Val Loss: 0.28448
# Epoch: 249 | Train Loss: 0.22080 | Val Loss: 0.28617
# Epoch: 250 | Train Loss: 0.22036 | Val Loss: 0.28262
# Saved model checkpoint to ./modelos/model_epoch_250.pth
# Epoch: 251 | Train Loss: 0.21654 | Val Loss: 0.28408
# Epoch: 252 | Train Loss: 0.21471 | Val Loss: 0.28113
# Epoch: 253 | Train Loss: 0.21641 | Val Loss: 0.28102
# Epoch: 254 | Train Loss: 0.21633 | Val Loss: 0.28422
# Epoch: 255 | Train Loss: 0.21836 | Val Loss: 0.28693
# Epoch: 256 | Train Loss: 0.22015 | Val Loss: 0.28688
# Epoch: 257 | Train Loss: 0.22166 | Val Loss: 0.28028
# Epoch: 258 | Train Loss: 0.21993 | Val Loss: 0.28430
# Epoch: 259 | Train Loss: 0.21958 | Val Loss: 0.27913
# Epoch: 260 | Train Loss: 0.21415 | Val Loss: 0.28300
# Epoch: 261 | Train Loss: 0.21684 | Val Loss: 0.29671
# Epoch: 262 | Train Loss: 0.22352 | Val Loss: 0.28315
# Epoch: 263 | Train Loss: 0.21777 | Val Loss: 0.28019
# Epoch: 264 | Train Loss: 0.21460 | Val Loss: 0.28401
# Epoch: 265 | Train Loss: 0.21084 | Val Loss: 0.28338
# Epoch: 266 | Train Loss: 0.21110 | Val Loss: 0.28166
# Epoch: 267 | Train Loss: 0.21007 | Val Loss: 0.28193
# Epoch: 268 | Train Loss: 0.21080 | Val Loss: 0.28478
# Epoch: 269 | Train Loss: 0.21179 | Val Loss: 0.28290
# Epoch: 270 | Train Loss: 0.21414 | Val Loss: 0.28062
# Epoch: 271 | Train Loss: 0.21249 | Val Loss: 0.28331
# Epoch: 272 | Train Loss: 0.21415 | Val Loss: 0.28597
# Epoch: 273 | Train Loss: 0.21416 | Val Loss: 0.27714
# Epoch: 274 | Train Loss: 0.21242 | Val Loss: 0.28724
# Epoch: 275 | Train Loss: 0.20850 | Val Loss: 0.28090
# Epoch: 276 | Train Loss: 0.20856 | Val Loss: 0.28174
# Epoch: 277 | Train Loss: 0.20985 | Val Loss: 0.27925
# Epoch: 278 | Train Loss: 0.21075 | Val Loss: 0.28600
# Epoch: 279 | Train Loss: 0.20799 | Val Loss: 0.28034
# Epoch: 280 | Train Loss: 0.21142 | Val Loss: 0.27694
# Epoch: 281 | Train Loss: 0.21116 | Val Loss: 0.28118
# Epoch: 282 | Train Loss: 0.21065 | Val Loss: 0.28665
# Epoch: 283 | Train Loss: 0.21094 | Val Loss: 0.28365
# Epoch: 284 | Train Loss: 0.20685 | Val Loss: 0.27876
# Epoch: 285 | Train Loss: 0.20908 | Val Loss: 0.27893
# Epoch: 286 | Train Loss: 0.20684 | Val Loss: 0.27769
# Epoch: 287 | Train Loss: 0.20660 | Val Loss: 0.27720
# Epoch: 288 | Train Loss: 0.20613 | Val Loss: 0.28175
# Epoch: 289 | Train Loss: 0.20689 | Val Loss: 0.27853
# Epoch: 290 | Train Loss: 0.21080 | Val Loss: 0.28287
# Epoch: 291 | Train Loss: 0.20918 | Val Loss: 0.28097
# Epoch: 292 | Train Loss: 0.20543 | Val Loss: 0.27783
# Epoch: 293 | Train Loss: 0.20256 | Val Loss: 0.28138
# Epoch: 294 | Train Loss: 0.20482 | Val Loss: 0.28175
# Epoch: 295 | Train Loss: 0.20432 | Val Loss: 0.28131
# Epoch: 296 | Train Loss: 0.20669 | Val Loss: 0.28303
# Epoch: 297 | Train Loss: 0.20844 | Val Loss: 0.27792
# Epoch: 298 | Train Loss: 0.20642 | Val Loss: 0.27935
# Epoch: 299 | Train Loss: 0.20619 | Val Loss: 0.27893
# Epoch: 300 | Train Loss: 0.20749 | Val Loss: 0.28641
# Saved model checkpoint to ./modelos/model_epoch_300.pth
# Epoch: 301 | Train Loss: 0.20731 | Val Loss: 0.28278
# Epoch: 302 | Train Loss: 0.20586 | Val Loss: 0.28082
# Epoch: 303 | Train Loss: 0.20565 | Val Loss: 0.28257
# Epoch: 304 | Train Loss: 0.20213 | Val Loss: 0.27886
# Epoch: 305 | Train Loss: 0.19977 | Val Loss: 0.27634
# Epoch: 306 | Train Loss: 0.20143 | Val Loss: 0.28243
# Epoch: 307 | Train Loss: 0.20404 | Val Loss: 0.28134
# Epoch: 308 | Train Loss: 0.20328 | Val Loss: 0.28367
# Epoch: 309 | Train Loss: 0.20175 | Val Loss: 0.27783
# Epoch: 310 | Train Loss: 0.20062 | Val Loss: 0.28232
# Epoch: 311 | Train Loss: 0.20258 | Val Loss: 0.28209
# Epoch: 312 | Train Loss: 0.20352 | Val Loss: 0.28264
# Epoch: 313 | Train Loss: 0.20201 | Val Loss: 0.27927
# Epoch: 314 | Train Loss: 0.20022 | Val Loss: 0.28333
# Epoch: 315 | Train Loss: 0.20097 | Val Loss: 0.28057
# Epoch: 316 | Train Loss: 0.20293 | Val Loss: 0.28214
# Epoch: 317 | Train Loss: 0.20397 | Val Loss: 0.28156
# Epoch: 318 | Train Loss: 0.20040 | Val Loss: 0.28013
# Epoch: 319 | Train Loss: 0.19818 | Val Loss: 0.28437
# Epoch: 320 | Train Loss: 0.20174 | Val Loss: 0.28677
# Epoch: 321 | Train Loss: 0.20526 | Val Loss: 0.28456
# Epoch: 322 | Train Loss: 0.20088 | Val Loss: 0.27638
# Epoch: 323 | Train Loss: 0.20068 | Val Loss: 0.28406
# Epoch: 324 | Train Loss: 0.20045 | Val Loss: 0.28306
# Epoch: 325 | Train Loss: 0.19895 | Val Loss: 0.27985
# Epoch: 326 | Train Loss: 0.19795 | Val Loss: 0.28049
# Epoch: 327 | Train Loss: 0.19845 | Val Loss: 0.28285
# Epoch: 328 | Train Loss: 0.19827 | Val Loss: 0.28117
# Epoch: 329 | Train Loss: 0.19880 | Val Loss: 0.28345
# Epoch: 330 | Train Loss: 0.19723 | Val Loss: 0.27751
# Epoch: 331 | Train Loss: 0.19581 | Val Loss: 0.28384
# Epoch: 332 | Train Loss: 0.19629 | Val Loss: 0.28217
# Epoch: 333 | Train Loss: 0.19795 | Val Loss: 0.27932
# Epoch: 334 | Train Loss: 0.19759 | Val Loss: 0.28363
# Epoch: 335 | Train Loss: 0.19874 | Val Loss: 0.28061
# Epoch: 336 | Train Loss: 0.19753 | Val Loss: 0.28034
# Epoch: 337 | Train Loss: 0.19640 | Val Loss: 0.27808
# Epoch: 338 | Train Loss: 0.19498 | Val Loss: 0.28107
# Epoch: 339 | Train Loss: 0.19498 | Val Loss: 0.27803
# Epoch: 340 | Train Loss: 0.19582 | Val Loss: 0.28367
# Detener entrenamiento en la época 339, la mejor pérdida fue 0.27634

# %%
# Guardamos el modelo
torch.save(model.state_dict(), "style_transfer_unet.pth")

# %%
import gc

#del model  # si ya lo tenías creado
#gc.collect()
#torch.cuda.empty_cache()

# %% [markdown]
# Probamos el modelo

# %%
# Cargo imagen de estilo
img_test = Image.open("lu_joaco.png").convert("RGB")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Cargo imagen de estilo
# ----> 2 img_test = Image.open("lu_joaco.png").convert("RGB")
#
# File ~/.conda/envs/Taller_DL_fixed/lib/python3.10/site-packages/PIL/Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
#    3512     filename = os.fspath(fp)
# -> 3513     fp = builtins.open(filename, "rb")
#    3514     exclusive_fp = True
#    3515 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lu_joaco.png'

# %%
img_test = style_transform(img_test).unsqueeze(0).to(DEVICE)

# %%
img_test.shape
# Out:
# torch.Size([1, 3, 256, 256])

# %%
img_test
# Out:
# tensor([[[[0.8371, 0.8371, 0.8371,  ..., 0.9758, 0.9745, 0.9744],
#           [0.7608, 0.7608, 0.7608,  ..., 0.9647, 0.9650, 0.9650],
#           [0.7608, 0.7608, 0.7608,  ..., 0.9652, 0.9679, 0.9683],
#           ...,
#           [0.4319, 0.3908, 0.4207,  ..., 0.3665, 0.3793, 0.3887],
#           [0.5181, 0.3788, 0.3124,  ..., 0.4286, 0.3723, 0.3613],
#           [0.4003, 0.4001, 0.3475,  ..., 0.4318, 0.4336, 0.3778]],
#
#          [[0.8225, 0.8225, 0.8225,  ..., 0.9077, 0.9065, 0.9063],
#           [0.7412, 0.7412, 0.7412,  ..., 0.8667, 0.8669, 0.8670],
#           [0.7412, 0.7412, 0.7412,  ..., 0.8671, 0.8698, 0.8703],
#           ...,
#           [0.3394, 0.3042, 0.3433,  ..., 0.2669, 0.2857, 0.2984],
#           [0.4260, 0.2924, 0.2361,  ..., 0.3225, 0.2762, 0.2740],
#           [0.3236, 0.3241, 0.2744,  ..., 0.3149, 0.3294, 0.2840]],
#
#          [[0.8118, 0.8118, 0.8118,  ..., 0.8276, 0.8264, 0.8262],
#           [0.7235, 0.7235, 0.7235,  ..., 0.7491, 0.7493, 0.7493],
#           [0.7180, 0.7180, 0.7180,  ..., 0.7485, 0.7513, 0.7517],
#           ...,
#           [0.1331, 0.0950, 0.1285,  ..., 0.0329, 0.0390, 0.0342],
#           [0.2165, 0.0801, 0.0245,  ..., 0.0708, 0.0348, 0.0159],
#           [0.1011, 0.0974, 0.0496,  ..., 0.0505, 0.0686, 0.0264]]]],
#        device='cuda:0')

# %%
with torch.no_grad():
            # estilo en [0,1] y normalizado a ImageNet
            output = model(img_test)

# %%
output
# Out:
# tensor([[[[ 1.2647e-02,  2.1223e-01, -1.1802e-01,  ..., -6.4929e-01,
#             1.3134e-01,  1.3560e+00],
#           [-5.6025e-01, -6.3435e-01, -7.9753e-01,  ..., -2.4230e-01,
#            -3.3348e-01,  5.5440e-01],
#           [-1.2037e-01, -6.9959e-01, -5.0326e-01,  ..., -2.3157e-01,
#             2.7657e-02,  3.4229e-01],
#           ...,
#           [-2.1074e-01, -3.5494e-01, -2.8926e-01,  ..., -7.9357e-01,
#            -6.6316e-01, -1.7067e-01],
#           [-1.2337e-02, -4.9698e-01, -6.2829e-01,  ..., -4.5232e-01,
#            -2.2928e-01, -3.1764e-01],
#           [ 1.9757e-01,  9.2091e-03, -2.0436e-01,  ...,  2.3296e-01,
#             7.1549e-02, -4.8066e-01]],
#
#          [[ 6.6963e-02,  2.0835e-01, -1.1676e-01,  ..., -6.1217e-01,
#             7.6438e-02,  1.2764e+00],
#           [-6.3769e-01, -6.5461e-01, -7.7488e-01,  ..., -1.4902e-01,
#            -4.1073e-01,  4.5562e-01],
#           [-1.6615e-01, -7.3830e-01, -4.4154e-01,  ..., -1.1790e-01,
#            -6.0037e-02,  2.6061e-01],
#           ...,
#           [-1.4860e-01, -3.5102e-01, -2.9844e-01,  ..., -7.9968e-01,
#            -7.1992e-01, -1.5247e-01],
#           [-3.4082e-03, -4.0728e-01, -6.2839e-01,  ..., -3.7005e-01,
#            -2.2561e-01, -3.5126e-01],
#           [ 4.1861e-02,  1.1112e-03, -2.6584e-01,  ..., -1.3696e-01,
#            -2.0871e-01, -8.1098e-01]],
#
#          [[ 8.8390e-02,  3.0232e-01,  1.5630e-01,  ..., -3.5415e-02,
#             2.8175e-01,  4.5552e-01],
#           [-6.7076e-01, -5.3766e-01, -5.3640e-01,  ...,  1.3914e-01,
#            -3.0967e-01,  1.7610e-01],
#           [-4.5879e-01, -6.1759e-01, -2.9713e-01,  ...,  5.5513e-02,
#            -3.3078e-01, -1.8425e-01],
#           ...,
#           [-1.1952e-02, -5.0071e-01, -5.7296e-01,  ..., -8.4626e-01,
#            -8.6109e-01, -3.7056e-01],
#           [-2.1892e-01, -4.9514e-01, -7.3217e-01,  ..., -7.9338e-01,
#            -5.3465e-01, -4.9918e-01],
#           [-2.4168e-01, -2.0186e-01, -3.3576e-01,  ..., -6.0941e-01,
#            -5.2166e-01, -1.0343e+00]]]], device='cuda:0')

# %%
import matplotlib.pyplot as plt

# %%
output = output.detach().cpu()

# %%
out_01 = (output + 1) / 2

# %%
img = out_01.squeeze(0).permute(1, 2, 0).numpy()

# %%
plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09972304..1.1780212].
